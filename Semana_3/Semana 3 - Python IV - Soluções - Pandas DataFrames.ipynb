# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# # Exercícios - Pandas DataFrames

# %% [markdown]
# Este notebook contém 27 exercícios focados em Pandas DataFrames.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1 - Converta a seguinte série num dataframe com 6 colunas e 8 linhas.
#
# series_a = pd.Series(np.random.randint (1, 10, 48))

# %%
series_a = pd.Series(np.random.randint(1, 10, 48))
df = pd.DataFrame(series_a.values.reshape([8,6]))
df
# Out:
#    0  1  2  3  4  5
# 0  1  8  4  6  8  7
# 1  2  1  1  2  2  7
# 2  8  2  8  3  5  3
# 3  9  8  2  8  2  2
# 4  6  1  6  5  5  8
# 5  3  7  9  3  1  9
# 6  4  7  4  7  7  8
# 7  3  9  9  4  7  9

# %% [markdown]
# 2 - Combine as seguintes séries e forme um dataframe.
#
# ser1 = pd.Series(np.arange(20))
#
# ser2 = pd.Series(list('abcedfghijklmnop'))

# %%
ser1 = pd.Series(np.arange(20))
ser2 = pd.Series(list('abcedfghijklmnop'))

pd.concat([ser1, ser2], axis=1)
# Out:
#      0    1
# 0    0    a
# 1    1    b
# 2    2    c
# 3    3    e
# 4    4    d
# 5    5    f
# 6    6    g
# 7    7    h
# 8    8    i
# 9    9    j
# 10  10    k
# 11  11    l
# 12  12    m
# 13  13    n
# 14  14    o
# 15  15    p
# 16  16  NaN
# 17  17  NaN
# 18  18  NaN
# 19  19  NaN

# %% [markdown]
# 3 - Crie um dataframe a partir do seguinte dicionário
#
# student_info = {
#     'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
#     'age': [21, 22, 20, 23, 22],
#     'grade': [85, 92, 78, 95, 88],
#     'city': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Miami']
# }

# %%
student_info = {
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'age': [21, 22, 20, 23, 22], 'grade': [85, 92, 78, 95, 88],
    'city': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Miami'] }

df = pd.DataFrame(student_info)
df
# Out:
#       name  age  grade         city
# 0    Alice   21     85     New York
# 1      Bob   22     92  Los Angeles
# 2  Charlie   20     78      Chicago
# 3    David   23     95      Houston
# 4      Eve   22     88        Miami

# %% [markdown]
# 4 - Especifique as seguintes etiquetas no dataframe anterior:
#
# tags = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
tags = ['a', 'b', 'c', 'd']
df.columns = tags
df
# Out:
#          a   b   c            d
# 0    Alice  21  85     New York
# 1      Bob  22  92  Los Angeles
# 2  Charlie  20  78      Chicago
# 3    David  23  95      Houston
# 4      Eve  22  88        Miami

# %% [markdown]
# 5 - Obtenha um resumo descritivo do dataframe anterior.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       5 non-null      object
#  1   b       5 non-null      int64
#  2   c       5 non-null      int64
#  3   d       5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes

# %% [markdown]
# 6 - Obtenha um resumo estatístico do dataframe anterior.

# %%
df.describe()
# Out:
#                b          c
# count   5.000000   5.000000
# mean   21.600000  87.600000
# std     1.140175   6.580274
# min    20.000000  78.000000
# 25%    21.000000  85.000000
# 50%    22.000000  88.000000
# 75%    22.000000  92.000000
# max    23.000000  95.000000

# %% [markdown]
# 7 - Quantas filas e colunas tem o dataframe?

# %%
df.shape
# Out:
# (10, 4)

# %%
print('columns: {}, rows: {}'.format(df.shape[1], df.shape[0]))
# Out:
# columns: 4, rows: 10

# %% [markdown]
# 8 - Imprima o nome de todas as colunas do dataframe.

# %%
df.columns
# Out:
# Index(['A', 'C', 'D'], dtype='object')

# %% [markdown]
# 9 - Extraia as 2 primeiras linhas do dataframe.

# %%
df.head(2)
# Out:
#        a   b   c            d
# 0  Alice  21  85     New York
# 1    Bob  22  92  Los Angeles

# %% [markdown]
# 10 - Escreva um programa que imprima as colunas 'a' e 'b' do dataframe.

# %%
df[['a', 'b']]
# Out:
#          a   b
# 0    Alice  21
# 1      Bob  22
# 2  Charlie  20
# 3    David  23
# 4      Eve  22

# %% [markdown]
# 11 - Substitua todos os valores da coluna 'a' por 'H' quando a coluna 'b' tem valor igual ou maior que 22.

# %%
df.loc[df['b'] >= 22, 'a'] = 'H'
df
# Out:
#          a   b   c            d
# 0    Alice  21  85     New York
# 1        H  22  92  Los Angeles
# 2  Charlie  20  78      Chicago
# 3        H  23  95      Houston
# 4        H  22  88        Miami

# %% [markdown]
# 12 - Selecione os casos em que a coluna 'c' tem valor acima de 90 e ordene esses casos consoante o conteúdo da coluna 'd'.

# %%
df[df['c'] > 90].sort_values(by='d')
# Out:
#    a   b   c            d
# 3  H  23  95      Houston
# 1  H  22  92  Los Angeles

# %% [markdown]
# 13 - Selecione os casos em que a coluna 'a' é diferente de 'H' ou a coluna 'c' é maior que 88.

# %%
df[(df['a']!='H') | (df['c']>88)]
# Out:
#          a   b   c            d
# 0    Alice  21  85     New York
# 1        H  22  92  Los Angeles
# 2  Charlie  20  78      Chicago
# 3        H  23  95      Houston

# %% [markdown]
# 14 - Crie um novo dataframe com o dicionário seguinte. Depois, verifique os casos em que a coluna 'B' não tem valores atribuídos.
#
# data = {'A': [1, 2, 3, 4],
#         'B': [5, np.nan, np.nan, 8],
#         'C': [9, 10, 11, 12]}

# %%
data = {'A': [1, 2, 3, 4],
        'B': [5, np.nan, np.nan, 8],
        'C': [9, 10, 11, 12]}

df = pd.DataFrame(data)
df['B'].isnull()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: B, dtype: bool

# %% [markdown]
# 15 - Calcule a soma do total da coluna 'A'.

# %%
df['A'].sum()
# Out:
# 10

# %% [markdown]
# 16 - Calcule a média dos valores da coluna 'C'.

# %%
df['C'].mean()
# Out:
# 10.5

# %% [markdown]
# 17 - Adicione a seguinte linha ao dataframe anterior.
#
# new_row = {'A': 5, 'B': 6, 'C': 7}

# %%
new_row = {'A': 5, 'B': 6, 'C': 7}
df = df.append(new_row, ignore_index=True)
df
# Out:
# <ipython-input-51-91dbbe5f9d0e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
#    A    B   C
# 0  1  5.0   9
# 1  2  NaN  10
# 2  3  NaN  11
# 3  4  8.0  12
# 4  5  6.0   7

# %% [markdown]
# 18 - Elimine a coluna 'B'.

# %%
df.drop(columns=['B'], inplace=True)
df
# Out:
#    A   C
# 0  1   9
# 1  2  10
# 2  3  11
# 3  4  12
# 4  5   7

# %% [markdown]
# 19 - Ordene o dataframe em ordem decrescente relativamente à coluna 'A' e em ordem ascendente relativamente à coluna 'D'.

# %%
df.sort_values(by=['A', 'C'], ascending=[False, True])
# Out:
#    A   C
# 4  5   7
# 3  4  12
# 2  3  11
# 1  2  10
# 0  1   9

# %% [markdown]
# 20 - Adicione uma coluna 'D' com os seguintes valores: [10, 20, 30, 40]

# %%
coluna_d = [10, 20, 30, 40, 50]
df['D'] = coluna_d
df
# Out:
#    A   C   D
# 0  1   9  10
# 1  2  10  20
# 2  3  11  30
# 3  4  12  40
# 4  5   7  50

# %% [markdown]
# 21 - Itere sobre cada coluna do dataframe para obter o resultado da seguinte operação para cada linha: **A * C / D**.

# %%
for index, row in df.iterrows():
    print(row['A'] * row['C'] / row['D'])
# Out:
# 0.9
# 1.0
# 1.1
# 1.2
# 0.7

# %% [markdown]
# 22 - Renomeie a coluna "A" para "B".

# %%
df = df.rename({'A':'B'}, axis=1)
df
# Out:
#    B   C   D
# 0  1   9  10
# 1  2  10  20
# 2  3  11  30
# 3  4  12  40
# 4  5   7  50

# %% [markdown]
# 23 - Para cada coluna, conte o número de nulls.

# %%
df.isna().sum()
# Out:
# B    0
# C    0
# D    0
# dtype: int64

# %% [markdown]
# 24 - Adicione uma nova coluna 'E' apenas com NaNs. Depois,substituia todos esses valores nulos por 0.

# %%
coluna_e = [np.nan, np.nan, np.nan, np.nan, np.nan]
df['E'] = coluna_e
df
# Out:
#    B   C   D   E
# 0  1   9  10 NaN
# 1  2  10  20 NaN
# 2  3  11  30 NaN
# 3  4  12  40 NaN
# 4  5   7  50 NaN

# %%
df.fillna(0, inplace=True)
df
# Out:
#    B   C   D    E
# 0  1   9  10  0.0
# 1  2  10  20  0.0
# 2  3  11  30  0.0
# 3  4  12  40  0.0
# 4  5   7  50  0.0

# %% [markdown]
# 25 - Esconda os índices de dataframe.

# %%
print(df.to_string(index=False))
# Out:
#  B  C  D   E
#  1  9 10 0.0
#  2 10 20 0.0
#  3 11 30 0.0
#  4 12 40 0.0
#  5  7 50 0.0

# %% [markdown]
# 26 - Dado o seguinte dataframe, selecione a linha com índice 2.
#
# col1 col2 col3
#
# 0 1 4 7
#
# 1 4 5 8
#
# 2 3 6 9
#
# 3 4 7 0
#
# 4 5 8 1

# %%
my_dict = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
df = pd.DataFrame(my_dict)
df
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1

# %%
df.iloc[[2]]
# Out:
#    col1  col2  col3
# 2     3     6     9

# %% [markdown]
# 27 - Crie o seguinte dataframe e selecione a linha que contém o valor máximo na coluna 2.
#
# d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}

# %%
d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}

df = pd.DataFrame(d)
df
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11

# %%
print(df.iloc[df["col2"].idxmax()])
# Out:
# col1    4
# col2    9
# col3    1
# Name: 3, dtype: int64
